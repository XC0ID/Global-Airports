# %% [markdown]
# ## 📦Library Setup
#
# ### What this cell does:
# This is the **foundation cell** of the notebook. We import every library that will be needed throughout the analysis:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# ## 📂 Load Dataset
#
# ### What this cell does:
# We load the raw CSV file into a **pandas DataFrame**. Before doing anything else, we:
# - Print the exact **shape** (rows × columns) so we know how big the dataset is
# - Print all **column names** to identify what data is available
# - Show the first **5 rows** (`head()`) as a quick sanity check that the file loaded correctly
#
# ### ⚙️ How to use this cell:
# 1. Download the CSV from the [Kaggle dataset page](https://www.kaggle.com/datasets/fareselgohary003/global-airports-dataset)
# 2. Place it in the **same folder** as this notebook
# 3. Change `FILE_PATH` below to match your exact filename if it differs from `airports.csv`
#
# ### 🔎 What to look for in the output:
# - The shape tells you the scale of data — expect ~55,000+ rows for a global dataset
# - Column names tell you what features are available (type, lat, lon, elevation, country, etc.)
# - The `head()` preview tells you if parsing was successful or if separator/encoding issues exist

# %%
df = pd.read_csv('data/airports.csv')
df.head()

# %%
df.info()
df.describe()

# %%
sns.histplot(df['latitude'])
plt.show()
